# %% [markdown]
# # Boolean Logic & Conditionals
#
# **By the end this notebook you will be able to:**
# - Use comparison and logical operators to write Boolean expressions
# - Predict whether an expression evaluates to `True` or `False`
# - Write `if` / `elif` / `else` statements to control program flow
# - Find and fix logic errors in conditional code

# %% [markdown]
# Check these print statements
# ```
# print(5 == 5)
# print(5 == "5")
# print(bool(0))
# print(bool(1))
# print(bool(""))
# print(bool("False"))
# ```

# %%
print(5==5)
print(5=="5")
print(bool(0))
print(bool(1))
print(bool(""))
print(bool("False"))
# Out:
# True
# False
# False
# True
# False
# True

# %% [markdown]
# ## Comparison Operators
#
# | Operator | Meaning |
# |---|---|
# | `==` | equal to |
# | `!=` | not equal to |
# | `>`  | greater than |
# | `<`  | less than |
# | `>=` | greater than or equal to |
# | `<=` | less than or equal to |
#
# **Note:** Common mistake: `=` assigns a value, `==` compares two values.

# %%
age = 20
print(age == 18)
print(age != 18)
print(age >= 18)
# Out:
# False
# True
# True

# %% [markdown]
# ### Activity — Fix the bug
#
# The code below is *supposed* to check if a student's has passing mark.
# It has a bug. Find it and fix it in the cell below.

# %%
score = 75
pass_mark = 40
is_passing = (score == pass_mark)
print(is_passing)
# Out:
# False

# %% [markdown]
# ## Logical Operators: `and`, `or`, `not`
#
# These combine multiple Boolean expressions into one.
#
# | Operator | Rule |
# |---|---|
# | `and` | `True` only if **both** sides are `True` |
# | `or`  | `True` if **at least one** side is `True` |
# | `not` | flips `True` ↔ `False` |

# %%
age = 20
has_id = True

print(age >= 18 and has_id)     # both must be True
print(age >= 18 or has_id)      # only one needs to be True
print(not has_id)               # flips the value
# Out:
# True
# True
# False

# %% [markdown]
# ### Activity — Truth table challenge
#
# For the variables below, **predict on paper** the output of each `print` statement
#
#
# ```
# a = True
# b = False
# c = True
#
# print(a and b)
# print(a or b)
# print(not c)
# print(a and (b or c))
# print((a and b) or (not c))
# ```

# %%
a = True
b = False
c = True

print(a and b)
print(a or b)
print(not c)
print(a and (b or c))
# Out:
# False
# True
# False
# True

# %% [markdown]
# By default, statements in Python script are executed sequentially from top to bottom. One way to alter this sequential flow of execution is:
#
# Conditional execution: a block of one or more statements will be executed if a certain expression is true

# %% [markdown]
# ## `if` / `elif` / `else`
#
# The condition can be a value, variable or expression. If the condition evaluates to True, then the statements within the if block are executed. Notice the four spaces before statement1, statement2, etc. The spaces inform Python that these statements are associated with the if statement above. This technique of structuring code by adding spaces is called indentation.
#
# We use Boolean expressions to **control which code runs**.
#
# ```python
# if condition:
#     # runs only if condition is True
# elif another_condition:
#     # runs only if the first was False and this is True
# else:
#     # runs if none of the above were True
# ```
#
# **Note:** Indentation matters in Python — it defines which lines belong to which block.
#
#
# ### The `elif` statement
#
# Python also provides an `elif` statement (short for "else if") to chain a series of conditional blocks. The conditions are evaluated one by one. For the first condition that evaluates to `True`, the block of statements below it is executed. The remaining conditions and statements are not evaluated. So, in an `if`, `elif`, `elif`... chain, at most one block of statements is executed, the one corresponding to the first condition that evaluates to `True`.

# %% [markdown]
# Create If Else statements and print grade with following rules.
# - marks scored above 90 = grade A
# - marks scored between 75 - 90 = grade B
# - marks scored between 60 - 75 = grade C
# - anything other = grade D

# %%
score = 85
if score > 90:
    print("Grade A")
elif score >= 75 and score <= 90:
    print("Grade B")
elif score >= 60 and score < 75:
    print("Grade C")
else:
    print("Grade D")

# %% [markdown]
# ### Activity — Build it yourself: Ticket Pricing
#
# Write a program that decides a movie ticket price based on age:
# - Age under 12 → ₹5
# - Age 12–17 → ₹8
# - Age 18–59 → ₹12
# - Age 60 and above → ₹7
#
# Store the age in a variable, use `if` / `elif` / `else`, and print the price.
# Test your code with **at least 4 different ages** (one for each category).

# %%
age = 20
if age < 12:
    print("₹5")
elif age >= 12 and age <= 17:
    print("₹8")
elif age >= 18 and age <= 59:
    print("₹12")
elif age >= 60:
    print("₹7")
else:
    print("Invalid age")
# Out:
# ₹12

# %% [markdown]
# ## Debug-the-Code Challenge
#
# Below is a program meant to check if a number is **positive, negative, or zero**, and whether it's **even or odd** — but it has 3 separate bugs.
#
# ### Activity — Find and fix all 3 bugs
# Fix the code in the cell below so that it correctly prints the right message for `number = -7`, `number = 0`, and `number = 8`.

# %%
number = 8

if number == 0:
    print("Zero")
elif number > 0:
    print("Positive")
else:
    print("Negative")

if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Positive
# Even

# %% [markdown]
# ### Nested conditional statements
#
# The code inside an `if` block can also include an `if` statement inside it. This pattern is called `nesting` and is used to check for another condition after a particular condition holds true.

# %% [markdown]
# ### Activity — Build a dummy login decision control
#
# Write a program to accept email id and password from user and take folloiwng decisions:
# - if details matches then provide success message.
# - if email id is correct but password then ask for password once more and check.
# - if none of the above then provide error message
#
# **Correct email credentials:**
# - emailid: ugcampus@iimb.ac.in
# - password: new_campus123

# %%
emailid = input("Enter your email id: ")
password = input("Enter your password: ")

if emailid == "vasumitra@iimb.ac.in" and password == "shinchan":
    print("Success")
else:
    print("Error")

# %% [markdown]
# ### Non-Boolean Conditions
#
# Note that conditions do not necessarily have to be booleans. In fact, a condition can be any value. The value is converted into a boolean automatically using the `bool` operator. This means that falsy values like `0`, `''`, `{}`, `[]`, etc. evaluate to `False` and all other values evaluate to `True`.

# %%
if '':
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to False

# %%
if 'Hello':
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to True

# %%
if None:
    print('The condition evaluted to True')
else:
    print('The condition evaluted to False')
# Out:
# The condition evaluted to False

# %% [markdown]
# ### Shorthand `if` conditional expression
#
# A frequent use case of the `if` statement involves testing a condition and setting a variable's value based on the condition.

# %%
a_number = 13

if a_number % 2 == 0:
    parity = 'even'
else:
    parity = 'odd'

print('The number {} is {}'.format(a_number, parity))
# Out:
# The number 13 is odd

# %% [markdown]
# Python provides a shorter syntax, which allows writing such conditions in a single line of code. It is known as a *conditional expression*, sometimes also referred to as a *ternary operator*. It has the following syntax:
#
# ```
# x = true_value if condition else false_value
# ```
#
# It has the same behavior as the following `if`-`else` block:
#
# ```
# if condition:
#     x = true_value
# else:
#     x = false_value
# ```
#
# Let's try it out for the example above.

# %%
# write short hand if statements for previous code

x = "even" if a_number % 2 == 0 else "odd"
print('The number {} is {}'.format(a_number, x))
# Out:
# The number 13 is odd

# %% [markdown]
# ### The `pass` statement
#
# `if` statements cannot be empty, there must be at least one statement in every `if` and `elif` block. You can use the `pass` statement to do nothing and avoid getting an error.

# %%
a_number = 9
if a_number % 2 == 0:
    pass
elif a_number % 3 == 0:
    print('{} is divisible by 3 but not divisible by 2')
# Out:
# {} is divisible by 3 but not divisible by 2

# %%
a_number = 9
if a_number % 2 == 0:
    pass
elif a_number % 3 == 0:
    print('{} is divisible by 3 but not divisible by 2'.format(a_number))
# Out:
# 9 is divisible by 3 but not divisible by 2
